# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
import pandas as pd
import numpy as np

# %%
# Your code here. 

student_data = pd.DataFrame(columns=['X','Y'])

student_data.X=[17,51,27,21,35,48,19,26,54,30]

student_data.Y=[10,1,5,9,4,2,9,6,0,3]

student_data
# Out:
#     X   Y
# 0  17  10
# 1  51   1
# 2  27   5
# 3  21   9
# 4  35   4
# 5  48   2
# 6  19   9
# 7  26   6
# 8  54   0
# 9  30   3

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
# Your code here.

import matplotlib.pyplot as plt

plt.scatter(student_data.X, student_data.Y, c='g', alpha=0.5)
plt.show()

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %% [markdown]
# **Your response here**
#
# *Es inversamente proporcional la edad a las faltas de los alumnos, es decir, a menor edad más faltas, por lo que a más edad, menos faltas.*

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
# Your response here.

student_data.corr()
# Out:
#           X         Y
# X  1.000000 -0.938575
# Y -0.938575  1.000000

# %%
student_data.cov()
# Out:
#             X          Y
# X  187.066667 -45.466667
# Y  -45.466667  12.544444

# %% [markdown]
# **Your response here**
#
# *La covarianza indica lo visto en el gráfico, que hay una relación inversamente proporcional entre X e Y ya que el signo entre X-Y es negativo. Gracias a la correlación, observamos que es muy elevada (muy próxima a -1) por lo que la relación lineal que tienen estas dos variables es muy alta.*

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
dfx=student_data.drop(columns='Y')
dfy=student_data.drop(columns='X')

# %%
# Your response here.

from sklearn.linear_model import LinearRegression as LinReg

lreg=LinReg()

lreg.fit(dfx, dfy)

y_pred=lreg.predict(dfx)

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
# Your code here.

plt.scatter(dfx, y_pred, c='b', alpha=0.5)
plt.show()

#prediccion

# %%
fig = plt.figure()

ax1 = fig.add_subplot(111)

ax1.scatter(student_data.X, student_data.Y, s=10, c='b', marker="s", label='initial')
ax1.scatter(dfx, y_pred, s=10, c='r', marker="x", label='lreg')
plt.legend(loc='upper right')
plt.show()

#solapados

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import warnings
warnings.filterwarnings('ignore')

x=sm.add_constant(student_data.X)

y=student_data.Y

modelo=sm.OLS(y, x).fit()

modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     59.18
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           5.78e-05
# Time:                        15:00:49   Log-Likelihood:                -15.669
# No. Observations:                  10   AIC:                             35.34
# Df Residuals:                       8   BIC:                             35.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.8721      1.114     11.551      0.000      10.302      15.442
# ...

# %%
# plot

x=np.linspace(student_data.X.min(), student_data.X.max(), 10)
y=-0.2431*x + 12.8721

plt.figure(figsize=(10, 5))

# la recta de ajuste
plt.plot(x, y, label='recta:{}x+{}'.format(-0.2431, 12.8721))

# datos
plt.scatter(student_data.X, student_data.Y, marker='o', c='y', label='inicial')

plt.title('Regresion lineal')
plt.xlabel('Edad')
plt.ylabel('Faltas')
plt.legend()
plt.show();

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
from sklearn.metrics import r2_score as r2

r2(dfy, y_pred)
# Out:
# 0.8809238964713726

# %% [markdown]
# **Your response here.**
#
# *El valor R2 evalúa la relación entre las dos variables entre 0-1 en una regresión lineal. Un valor de 0.88 indica que el 88% de la variable dependiente es predicha por la variable independiente. No podemos afirmar con rotundidad que hay una relación muy estrecha entre ambas variables pero su relación lineal es evidente.*

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
# Import any libraries you may need & the data

veh=pd.read_csv('../data/vehicles.csv')

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
# Your response here. 

veh.corr()
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.037876   0.082469
# Engine Displacement      0.037876             1.000000   0.901858
# Cylinders                0.082469             0.901858   1.000000
# Fuel Barrels/Year       -0.221084             0.789752   0.739517
# City MPG                 0.161818            -0.740317  -0.703866
# Highway MPG              0.267259            -0.715039  -0.650287
# Combined MPG             0.204751            -0.746782  -0.698648
# CO2 Emission Grams/Mile -0.222300             0.803520   0.752393
# Fuel Cost/Year          -0.091913             0.769678   0.778153
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.221084  0.161818     0.267259
# Engine Displacement               0.789752 -0.740317    -0.715039
# Cylinders                         0.739517 -0.703866    -0.650287
# ...

# %% [markdown]
# **Response**
#
# *Las variables más relacionadas con CO2 emission son: Fuel barrels/years, Fuel cost/year, Engine Displacement, Cylidnes (su valor de correlación es superior a 0.75 sobre 1). Igualmente, estas variables están relacionadas entre sí con valores altos de correlación, por lo que se pueden prescindir de alguna de ellas al estar relacionadas.*

# %%
import seaborn as sns

plt.figure(figsize=(15, 10))

sns.set(style='white')

mask=np.triu(np.ones_like(veh.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)


sns.heatmap(veh.corr(),
           mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %%
#Elimino columnas numéricas que no aportan valor

vehicles=veh.drop(columns=['Year', 'City MPG', 'Highway MPG', 'Combined MPG' ])

#Elimino columnas categóricas que no aportan valor

vehicles=vehicles.drop(columns=['Make', 'Model', 'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type' ])

vehicles.corr()
# Out:
#                          Engine Displacement  Cylinders  Fuel Barrels/Year  \
# Engine Displacement                 1.000000   0.901858           0.789752
# Cylinders                           0.901858   1.000000           0.739517
# Fuel Barrels/Year                   0.789752   0.739517           1.000000
# CO2 Emission Grams/Mile             0.803520   0.752393           0.986189
# Fuel Cost/Year                      0.769678   0.778153           0.916208
#
#                          CO2 Emission Grams/Mile  Fuel Cost/Year
# Engine Displacement                     0.803520        0.769678
# Cylinders                               0.752393        0.778153
# Fuel Barrels/Year                       0.986189        0.916208
# CO2 Emission Grams/Mile                 1.000000        0.930865
# Fuel Cost/Year                          0.930865        1.000000

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here. 

from sklearn.model_selection import train_test_split as tts      # el alias es mio

X=vehicles.drop(columns='CO2 Emission Grams/Mile')

y=vehicles['CO2 Emission Grams/Mile']


X_train, X_test, y_train, y_test = tts(X, y, train_size=0.8, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((28761, 4), (7191, 4), (28761,), (7191,))

# %%
from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.metrics import mean_squared_error as mse

rfr=RFR()

rfr.fit(X_train, y_train)

y_pred=rfr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 2.664110794504093

# %%
from xgboost import XGBRegressor as XGBR

xgbr=XGBR()

xgbr.fit(X_train, y_train)

y_pred=xgbr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 2.65073205643244

# %%
from sklearn.ensemble import GradientBoostingRegressor as GBR

gbr=GBR()

gbr.fit(X_train, y_train)

y_pred=gbr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 3.0072090149417177

# %%
from lightgbm import LGBMRegressor as LGBMR

lgbmr=LGBMR()

lgbmr.fit(X_train, y_train)

y_pred=lgbmr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 3.2280861657101885

# %%
from catboost import CatBoostRegressor as CTR

ctr=CTR()

ctr.fit(X_train, y_train)

y_pred=ctr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# Learning rate set to 0.06961
# 0:	learn: 111.5832973	total: 3.42ms	remaining: 3.42s
# 1:	learn: 104.4581788	total: 6.33ms	remaining: 3.16s
# 2:	learn: 97.8000242	total: 10.3ms	remaining: 3.41s
# 3:	learn: 91.6116574	total: 13.1ms	remaining: 3.27s
# 4:	learn: 85.7880244	total: 16.2ms	remaining: 3.22s
# 5:	learn: 80.3090711	total: 19.3ms	remaining: 3.2s
# 6:	learn: 75.3180439	total: 22.2ms	remaining: 3.14s
# 7:	learn: 70.5925262	total: 25.4ms	remaining: 3.15s
# 8:	learn: 66.1491946	total: 27.9ms	remaining: 3.07s
# 9:	learn: 62.2370206	total: 30.3ms	remaining: 3s
# 10:	learn: 58.5937196	total: 32.7ms	remaining: 2.94s
# 11:	learn: 54.9566711	total: 35.2ms	remaining: 2.9s
# 12:	learn: 51.5436475	total: 37.6ms	remaining: 2.85s
# 13:	learn: 48.3799242	total: 40ms	remaining: 2.82s
# 14:	learn: 45.4561884	total: 42.4ms	remaining: 2.78s
# 15:	learn: 42.7087720	total: 44.7ms	remaining: 2.75s
# 16:	learn: 40.1206429	total: 47.2ms	remaining: 2.73s
# ...

# %% [markdown]
# **Response**
#
# *Se realiza la predicción con Engine Displacement/Cylinders/Fuel Barrels/Year/Cost/Year (variables correlacionadas) con respecto a CO2 Emission Grams/Mile con varios modelos de regresión, resultando el más óptimo el XGBoost ("Extreme Gradient Boosting") obteniendo un valor de error cuadrático medio de 2.65, el más bajo, con respecto a CTR (2.67), LGMR (3.23), GBR (3.01), RFR (2.66).*

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
# Your response here. 

import statsmodels.api as sm
from statsmodels.formula.api import ols

x=sm.add_constant(X) 

modelo=sm.OLS(y, x).fit()

pred=modelo.predict(x)

modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     CO2 Emission Grams/Mile   R-squared:                       0.978
# Model:                                 OLS   Adj. R-squared:                  0.978
# Method:                      Least Squares   F-statistic:                 4.059e+05
# Date:                     Wed, 30 Nov 2022   Prob (F-statistic):               0.00
# Time:                             15:13:27   Log-Likelihood:            -1.5396e+05
# No. Observations:                    35952   AIC:                         3.079e+05
# Df Residuals:                        35947   BIC:                         3.080e+05
# Df Model:                                4
# Covariance Type:                 nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Response**
#
# *El pvalor de las cuatro variables es igual a 0, indicando que son relevantes para el ensayo al estar relacionadas con la emisión de CO2. El R2 es de casi 0.98 por lo que el 98% de la variables dependiente es predicha por las variables independientes. El índice de correlación es alto, favoreciendo la relación entre las variables. El error estandar de cada variable es bajo, favoreciendo la fiabilidad del análisis. Por lo tanto, la predicción es efectiva para estas cuatro variables relacionadas con la emisión de CO2.*

# %% [markdown]
# ## Bonus Challenge: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
# Your code here. 

df=pd.DataFrame(data={'X':[1,3,4,6,8,9,11,14], 'Y':[1,2,4,4,5,7,8,13]})

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
# Your code here.

plt.scatter(df.X,df.Y)
plt.show;

# %%
x=sm.add_constant(df.X)

y=df.Y

modelo=sm.OLS(y, x).fit()

modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     81.81
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           0.000102
# Time:                        15:22:48   Log-Likelihood:                -10.800
# No. Observations:                   8   AIC:                             25.60
# Df Residuals:                       6   BIC:                             25.76
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4394      0.759     -0.579      0.584      -2.297       1.418
# ...

# %%
x=np.linspace(df.X.min(), df.X.max(), 10)
y=0.8485*x -0.4394

plt.figure(figsize=(10, 5))

# la recta de ajuste
plt.plot(x, y, label='recta:{}x+{}'.format(0.8485, -0.4394))

# datos
plt.scatter(df.X, df.Y, marker='o', c='y', label='data')

plt.title('Regresion lineal')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show();

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %% [markdown]
# **Your response here.**
#
# *R2 es de 0.93 que indica una buena correlación entre las muestras. Posiblemente mejoraría sin el último valor que parece estar fuera de rango.*

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Your response here. 

df1=pd.DataFrame(data={'X':[1,3,4,6,8,9,11], 'Y':[1,2,4,4,5,7,8]})

x=sm.add_constant(df1.X)

y=df1.Y

modelo=sm.OLS(y, x).fit()

modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     83.31
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           0.000264
# Time:                        15:29:14   Log-Likelihood:                -5.7771
# No. Observations:                   7   AIC:                             15.55
# Df Residuals:                       5   BIC:                             15.45
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3233      0.513      0.630      0.556      -0.996       1.642
# ...

# %%
x=np.linspace(df1.X.min(), df1.X.max(), 10)
y=0.6842*x + 0.3233

plt.figure(figsize=(10, 5))

# la recta de ajuste
plt.plot(x, y, label='recta:{}x+{}'.format(0.6842, 0.3233))

# datos
plt.scatter(df1.X, df1.Y, marker='o', c='y', label='data')

plt.title('Regresion lineal')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show();

# %% [markdown]
# **Response**
#
# *Mejoran los intervalos, el R2 es ligeramente mayor y baja el error estándar.*

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %% [markdown]
# **Your response here.**
#
#
# *La recta se ajusta mejor sin el posible outlier del último dato y así poder afirmar que existe una relación estrecha entre X e Y. A pesar de este dato, podría mantenerse ya que los resultados, a priori, no son malos, pero podría mejorarse con la eliminación de este dato.*
